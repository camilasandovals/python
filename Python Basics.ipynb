# %% [markdown]
# # Intro to Python
# This notebook has some basic Python commands

# %%
name = "Camila"
age = 26
awesome = True

# %%
print(name)
# Out:
# Camila

# %%
def bouncer(age):
    if(age >= 21):
        return "You can drink"
    if(age >=18):
        return "You can dance"
    return "Get out"

# %%
bouncer(12)
# Out:
# 'Get out'

# %%
bouncer(47)
# Out:
# 'You can drink'

# %%
for i in range(0,10):
    print("Python is cool")
# Out:
# Python is cool
# Python is cool
# Python is cool
# Python is cool
# Python is cool
# Python is cool
# Python is cool
# Python is cool
# Python is cool
# Python is cool

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
data = pd.DataFrame(np.random.randn(100,4), columns=['A', 'B', 'C', 'D'])

# %%
data.head()
# Out:
#           A         B         C         D
# 0 -2.332007 -1.018251 -0.310234 -0.592953
# 1  0.790806  0.299033 -0.859705  0.045516
# 2 -0.051595 -0.399813  0.354729 -1.639223
# 3  1.279630  0.557050  1.439038  1.482760
# 4 -1.574373  0.291421 -0.911220 -2.742434

# %%
plt.scatter(data['A'], data['D'])

# %%
sns.pairplot(data)
